# %%
import pandas as pd

# %%
data = pd.read_csv('E-Scooter_Trips.csv')

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1491790 entries, 0 to 1491789
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   Trip ID                      1491790 non-null  object
#  1   Start Time                   1491790 non-null  object
#  2   End Time                     1491790 non-null  object
#  3   Trip Distance                1491790 non-null  int64
#  4   Trip Duration                1491790 non-null  int64
#  5   Vendor                       1491790 non-null  object
#  6   Start Community Area Number  1490831 non-null  float64
#  7   End Community Area Number    1490356 non-null  float64
#  8   Start Community Area Name    1490831 non-null  object
#  9   End Community Area Name      1490356 non-null  object
#  10  Start Centroid Latitude      1490831 non-null  float64
#  11  Start Centroid Longitude     1490831 non-null  float64
# ...

# %%
print(data.head())
print(data.isnull().sum())
# Out:
#                                 Trip ID              Start Time  \
# 0  17553846-c8d6-b9de-1755-3846c8d6b9de  05/28/2022 02:00:00 PM
# 1  1756d4dc-ccf1-af42-1756-d4dcccf1af42  05/29/2022 07:00:00 PM
# 2  1756d578-f376-9950-1756-d578f3769950  05/29/2022 08:00:00 PM
# 3  1756fc61-f058-c200-1756-fc61f058c200  05/29/2022 10:00:00 PM
# 4  17659074-0cfd-92ca-1765-90740cfd92ca  06/10/2022 12:00:00 AM
#
#                  End Time  Trip Distance  Trip Duration Vendor  \
# 0  05/28/2022 03:00:00 PM           2484           1544   Lyft
# 1  05/29/2022 08:00:00 PM             36            135   Lyft
# 2  05/29/2022 08:00:00 PM           2653           1972   Lyft
# 3  05/29/2022 10:00:00 PM            105            137   Lyft
# 4  06/10/2022 12:00:00 AM           2299            540   Lyft
#
#    Start Community Area Number  End Community Area Number  \
# 0                         32.0                       32.0
# 1                         32.0                       32.0
# ...

# %%
avg_trip_duration = data['Trip Duration'].mean()
print(f"Average Trip Duration: {avg_trip_duration:.2f} minutes")
# Out:
# Average Trip Duration: 908.50 minutes

# %%
avg_trip_distance = data['Trip Distance'].mean()
print(f"Average Trip Distance: {avg_trip_distance:.2f} Miles")
# Out:
# Average Trip Distance: 2600.54 Miles

# %%
trips_per_vendor = data['Vendor'].value_counts()

print("Number of Trips per Vendor:")
print(trips_per_vendor)
# Out:
# Number of Trips per Vendor:
# Lyft    737259
# Lime    580181
# Spin    106554
# Link     67796
# Name: Vendor, dtype: int64

# %%
plt.figure(figsize=(10, 6))
trips_per_vendor.plot(kind='bar', color='blue')
plt.title('Number of Trips per Vendor')
plt.xlabel('Vendor')
plt.ylabel('Number of Trips')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
trips_per_community = data['Start Community Area Name'].value_counts()
trips_top_10_community = trips_per_community.head(10)
print("Number Trips in top 10 community area:")
print(trips_top_10_community)
# Out:
# Number Trips in top 10 community area:
# Near North Side    233742
# Near West Side     184907
# Loop               171871
# West Town          112246
# Lincoln Park       101643
# Lake View           72768
# Logan Square        46027
# Near South Side     26478
# Belmont Cragin      24590
# Uptown              23942
# Name: Start Community Area Name, dtype: int64

# %%
plt.figure(figsize=(10, 6))
plt.scatter(trips_top_10_community.index, trips_top_10_community.values, color='dodgerblue')
plt.title('Number of Trips in Top 10 Community Areas')
plt.xlabel('Community Area')
plt.ylabel('Number of Trips')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
